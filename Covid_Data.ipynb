# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("covid19_region.csv")
df
# Out:
#       Unnamed: 0                 date  ... Unnamed: 19  Unnamed: 20
# 0              0  2020-02-24T18:00:00  ...         NaN          NaN
# 1              1  2020-02-24T18:00:00  ...         NaN          NaN
# 2              2  2020-02-24T18:00:00  ...         NaN          NaN
# 3              3  2020-02-24T18:00:00  ...         NaN          NaN
# 4              4  2020-02-24T18:00:00  ...         NaN          NaN
# ...          ...                  ...  ...         ...          ...
# 1465        1465  2020-05-03T17:00:00  ...         NaN          NaN
# 1466        1466  2020-05-03T17:00:00  ...         NaN          NaN
# 1467        1467  2020-05-03T17:00:00  ...         NaN          NaN
# 1468        1468  2020-05-03T17:00:00  ...         NaN          NaN
# 1469        1469  2020-05-03T17:00:00  ...         NaN          NaN
#
# [1470 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date', 'state', 'region_code', 'region', 'lat', 'long',
#        'hospitalized_with_symptoms', 'intensive_care', 'total_hospitalized',
#        'home_quarantine', 'total_confirmed_cases', 'variation_total_confirmed',
#        'new_confirmed_cases', 'recovered', 'deaths', 'total_cases',
#        'swabs_made', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                       0
# date                             0
# state                            0
# region_code                      0
# region                           0
# lat                              0
# long                             0
# hospitalized_with_symptoms       0
# intensive_care                   0
# total_hospitalized               0
# home_quarantine                  0
# total_confirmed_cases            0
# variation_total_confirmed        0
# new_confirmed_cases              0
# recovered                        0
# deaths                           0
# total_cases                      0
# swabs_made                       0
# Unnamed: 18                   1155
# Unnamed: 19                   1448
# Unnamed: 20                   1448
# dtype: int64

# %%
df.drop(['Unnamed: 0','date','lat','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-3d9770f6a8cc> in <module>()
# ----> 1 df.drop(['Unnamed: 0','date','lat','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1,inplace=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4172             level=level,
#    4173             inplace=inplace,
# -> 4174             errors=errors,
#    4175         )
#    4176
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3887         for axis, labels in axes.items():
#    3888             if labels is not None:
# -> 3889                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3890
#    3891         if inplace:
#
# ...

# %%
df
# Out:
#      state  region_code         region  ...  deaths  total_cases  swabs_made
# 0      ITA           13        Abruzzo  ...       0            0           5
# 1      ITA           17     Basilicata  ...       0            0           0
# 2      ITA            4   P.A. Bolzano  ...       0            0           1
# 3      ITA           18       Calabria  ...       0            0           1
# 4      ITA           15       Campania  ...       0            0          10
# ...    ...          ...            ...  ...     ...          ...         ...
# 1465   ITA            9        Toscana  ...     872         9563      150914
# 1466   ITA            4    P.A. Trento  ...     429         4247       41095
# 1467   ITA           10         Umbria  ...      68         1394       38823
# 1468   ITA            2  Valle d'Aosta  ...     138         1142        8100
# 1469   ITA            5         Veneto  ...    1516        18318      378202
#
# [1470 rows x 15 columns]

# %%
sns.relplot(x="total_cases",y="recovered",data=df)

# %%
sns.relplot(x="total_cases",y="total_confirmed_cases",data=df)

# %%
sns.relplot(x="hospitalized_with_symptoms",y="total_confirmed_cases",data=df)

# %%
sns.relplot(x="total_confirmed_cases",y="hospitalized_with_symptoms",data=df)

# %%
sns.relplot(x="total_confirmed_cases",y="hospitalized_with_symptoms",hue='recovered',data=df)

# %%
sns.pairplot(df)

# %%
sns.relplot(x="total_cases",y="home_quarantine",kind='line',data=df)

# %%
sns.catplot(x="total_cases",y="recovered",data=df)
